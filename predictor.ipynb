# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('la_liga_2014_2025_all_matches_final.csv')

# %%
df
# Out:
#       match_id             date       home_team            away_team  \
# 0         5826  8/23/2014 18:00          Malaga        Athletic Club
# 1         5827  8/23/2014 20:00         Sevilla             Valencia
# 2         5828  8/23/2014 20:00         Granada  Deportivo La Coruna
# 3         5829  8/23/2014 22:00         Almeria             Espanyol
# 4         5830  8/24/2014 18:00           Eibar        Real Sociedad
# ...        ...              ...             ...                  ...
# 4175     27359  5/24/2025 19:00          Getafe           Celta Vigo
# 4176     27360  5/24/2025 19:00  Rayo Vallecano             Mallorca
# 4177     27358  5/25/2025 12:00          Girona      Atletico Madrid
# 4178     27361  5/25/2025 14:15      Villarreal              Sevilla
# 4179     27353  5/25/2025 19:00   Athletic Club            Barcelona
#
#       home_goals  away_goals  home_xg  away_xg  home_shots  away_shots  \
# ...

# %%
df['away_team'].unique()
# Out:
# array(['Athletic Club', 'Valencia', 'Deportivo La Coruna', 'Espanyol',
#        'Real Sociedad', 'Elche', 'Getafe', 'Villarreal', 'Cordoba',
#        'Atletico Madrid', 'Almeria', 'Malaga', 'Celta Vigo', 'Levante',
#        'Eibar', 'Sevilla', 'Barcelona', 'Rayo Vallecano', 'Real Madrid',
#        'Granada', 'Las Palmas', 'Sporting Gijon', 'Real Betis', 'Osasuna',
#        'Alaves', 'Leganes', 'Girona', 'Real Valladolid', 'SD Huesca',
#        'Mallorca', 'Cadiz'], dtype=object)

# %%
def results(home_goals, away_goals):
    if home_goals > away_goals:
        return "home"

    elif away_goals > home_goals:
        return "away"

    else:
        return "draw"


df["Result"] = df.apply(lambda row: results(row["home_goals"], row["away_goals"]), axis=1)

# %%
df.head()
# Out:
#    match_id             date home_team            away_team  home_goals  \
# 0      5826  8/23/2014 18:00    Malaga        Athletic Club           1
# 1      5827  8/23/2014 20:00   Sevilla             Valencia           1
# 2      5828  8/23/2014 20:00   Granada  Deportivo La Coruna           2
# 3      5829  8/23/2014 22:00   Almeria             Espanyol           1
# 4      5830  8/24/2014 18:00     Eibar        Real Sociedad           1
#
#    away_goals  home_xg  away_xg  home_shots  away_shots  home_sot  away_sot  \
# 0           0     1.32     1.14          12          12         3         5
# 1           1     1.17     1.75          12          11         3         1
# 2           1     0.55     0.38          10           8         3         1
# 3           1     0.98     0.40          19          12         6         2
# 4           0     0.47     0.98          12          19         5         4
#
#    home_deep  away_deep  home_ppda  away_ppda  home_xpts  away_xpts  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4180 entries, 0 to 4179
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   match_id       4180 non-null   int64
#  1   date           4180 non-null   object
#  2   home_team      4180 non-null   object
#  3   away_team      4180 non-null   object
#  4   home_goals     4180 non-null   int64
#  5   away_goals     4180 non-null   int64
#  6   home_xg        4180 non-null   float64
#  7   away_xg        4180 non-null   float64
#  8   home_shots     4180 non-null   int64
#  9   away_shots     4180 non-null   int64
#  10  home_sot       4180 non-null   int64
#  11  away_sot       4180 non-null   int64
#  12  home_deep      4180 non-null   int64
#  13  away_deep      4180 non-null   int64
#  14  home_ppda      4180 non-null   float64
#  15  away_ppda      4180 non-null   float64
#  16  home_xpts      4180 non-null   float64
# ...

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#    match_id                date home_team            away_team  home_goals  \
# 0      5826 2014-08-23 18:00:00    Malaga        Athletic Club           1
# 1      5827 2014-08-23 20:00:00   Sevilla             Valencia           1
# 2      5828 2014-08-23 20:00:00   Granada  Deportivo La Coruna           2
# 3      5829 2014-08-23 22:00:00   Almeria             Espanyol           1
# 4      5830 2014-08-24 18:00:00     Eibar        Real Sociedad           1
#
#    away_goals  home_xg  away_xg  home_shots  away_shots  home_sot  away_sot  \
# 0           0     1.32     1.14          12          12         3         5
# 1           1     1.17     1.75          12          11         3         1
# 2           1     0.55     0.38          10           8         3         1
# 3           1     0.98     0.40          19          12         6         2
# 4           0     0.47     0.98          12          19         5         4
#
# ...

# %%
df = df.sort_values(by='date', ascending=True).reset_index(drop=True)

# %%
df.head()
# Out:
#    match_id                date home_team            away_team  home_goals  \
# 0      5826 2014-08-23 18:00:00    Malaga        Athletic Club           1
# 1      5827 2014-08-23 20:00:00   Sevilla             Valencia           1
# 2      5828 2014-08-23 20:00:00   Granada  Deportivo La Coruna           2
# 3      5829 2014-08-23 22:00:00   Almeria             Espanyol           1
# 4      5830 2014-08-24 18:00:00     Eibar        Real Sociedad           1
#
#    away_goals  home_xg  away_xg  home_shots  away_shots  home_sot  away_sot  \
# 0           0     1.32     1.14          12          12         3         5
# 1           1     1.17     1.75          12          11         3         1
# 2           1     0.55     0.38          10           8         3         1
# 3           1     0.98     0.40          19          12         6         2
# 4           0     0.47     0.98          12          19         5         4
#
# ...

# %%
def match_points(home_goals, away_goals):
    if home_goals > away_goals:
        return 3
    elif home_goals == away_goals:
        return 2
    else:
        return 1

# Initialize rolling form column
df['home_form_points_avg'] = 1.0  # default for first 5 matches

# Compute rolling average form for each home team
teams = df['home_team'].unique()

for team in teams:
    team_matches_idx = df[df['home_team'] == team].index.tolist()
    
    for i in range(len(team_matches_idx)):
        idx = team_matches_idx[i]
        if i >= 5:  # from 6th match onward
            last5_idx = team_matches_idx[i-5:i]
            points = [match_points(df.at[j, 'home_goals'], df.at[j, 'away_goals']) for j in last5_idx]
            df.at[idx, 'home_form_points_avg'] = sum(points) / 5  # divide by 5 to get average

print(df[['date','home_team','away_team','home_goals','away_goals','home_form_points_avg']])
# Out:
#                     date      home_team            away_team  home_goals  \
# 0    2014-08-23 18:00:00         Malaga        Athletic Club           1
# 1    2014-08-23 20:00:00        Sevilla             Valencia           1
# 2    2014-08-23 20:00:00        Granada  Deportivo La Coruna           2
# 3    2014-08-23 22:00:00        Almeria             Espanyol           1
# 4    2014-08-24 18:00:00          Eibar        Real Sociedad           1
# ...                  ...            ...                  ...         ...
# 4175 2025-05-24 19:00:00         Alaves              Osasuna           1
# 4176 2025-05-24 19:00:00         Getafe           Celta Vigo           1
# 4177 2025-05-25 12:00:00         Girona      Atletico Madrid           0
# 4178 2025-05-25 14:15:00     Villarreal              Sevilla           4
# 4179 2025-05-25 19:00:00  Athletic Club            Barcelona           0
#
#       away_goals  home_form_points_avg
# 0              0                   1.0
# ...

# %%
df.head()
# Out:
#    match_id                date home_team            away_team  home_goals  \
# 0      5826 2014-08-23 18:00:00    Malaga        Athletic Club           1
# 1      5827 2014-08-23 20:00:00   Sevilla             Valencia           1
# 2      5828 2014-08-23 20:00:00   Granada  Deportivo La Coruna           2
# 3      5829 2014-08-23 22:00:00   Almeria             Espanyol           1
# 4      5830 2014-08-24 18:00:00     Eibar        Real Sociedad           1
#
#    away_goals  home_xg  away_xg  home_shots  away_shots  ...  away_sot  \
# 0           0     1.32     1.14          12          12  ...         5
# 1           1     1.17     1.75          12          11  ...         1
# 2           1     0.55     0.38          10           8  ...         1
# 3           1     0.98     0.40          19          12  ...         2
# 4           0     0.47     0.98          12          19  ...         4
#
#    home_deep  away_deep  home_ppda  away_ppda  home_xpts  away_xpts  \
# ...

# %%
def match_points(home_goals, away_goals):
    if home_goals > away_goals:
        return 3
    elif home_goals == away_goals:
        return 2
    else:
        return 1

# Initialize rolling form columns
df['home_form_points_avg'] = 1.0  # first 5 matches default
df['away_form_points_avg'] = 1.0

# Compute rolling average form for each home team
teams = df['home_team'].unique()
for team in teams:
    team_matches_idx = df[df['home_team'] == team].index.tolist()
    for i in range(len(team_matches_idx)):
        idx = team_matches_idx[i]
        if i >= 5:
            last5_idx = team_matches_idx[i-5:i]
            points = [match_points(df.at[j, 'home_goals'], df.at[j, 'away_goals']) for j in last5_idx]
            df.at[idx, 'home_form_points_avg'] = sum(points) / 5

# Compute rolling average form for each away team
away_teams = df['away_team'].unique()
for team in away_teams:
    team_matches_idx = df[df['away_team'] == team].index.tolist()
    for i in range(len(team_matches_idx)):
        idx = team_matches_idx[i]
        if i >= 5:
            last5_idx = team_matches_idx[i-5:i]
            points = [match_points(df.at[j, 'away_goals'], df.at[j, 'home_goals']) for j in last5_idx]
            df.at[idx, 'away_form_points_avg'] = sum(points) / 5

# Show result
print(df[['date','home_team','away_team','home_goals','away_goals','home_form_points_avg','away_form_points_avg']])
# Out:
#                     date      home_team            away_team  home_goals  \
# 0    2014-08-23 18:00:00         Malaga        Athletic Club           1
# 1    2014-08-23 20:00:00        Sevilla             Valencia           1
# 2    2014-08-23 20:00:00        Granada  Deportivo La Coruna           2
# 3    2014-08-23 22:00:00        Almeria             Espanyol           1
# 4    2014-08-24 18:00:00          Eibar        Real Sociedad           1
# ...                  ...            ...                  ...         ...
# 4175 2025-05-24 19:00:00         Alaves              Osasuna           1
# 4176 2025-05-24 19:00:00         Getafe           Celta Vigo           1
# 4177 2025-05-25 12:00:00         Girona      Atletico Madrid           0
# 4178 2025-05-25 14:15:00     Villarreal              Sevilla           4
# 4179 2025-05-25 19:00:00  Athletic Club            Barcelona           0
#
#       away_goals  home_form_points_avg  away_form_points_avg
# ...

# %%
df
# Out:
#       match_id                date      home_team            away_team  \
# 0         5826 2014-08-23 18:00:00         Malaga        Athletic Club
# 1         5827 2014-08-23 20:00:00        Sevilla             Valencia
# 2         5828 2014-08-23 20:00:00        Granada  Deportivo La Coruna
# 3         5829 2014-08-23 22:00:00        Almeria             Espanyol
# 4         5830 2014-08-24 18:00:00          Eibar        Real Sociedad
# ...        ...                 ...            ...                  ...
# 4175     27356 2025-05-24 19:00:00         Alaves              Osasuna
# 4176     27359 2025-05-24 19:00:00         Getafe           Celta Vigo
# 4177     27358 2025-05-25 12:00:00         Girona      Atletico Madrid
# 4178     27361 2025-05-25 14:15:00     Villarreal              Sevilla
# 4179     27353 2025-05-25 19:00:00  Athletic Club            Barcelona
#
#       home_goals  away_goals  home_xg  away_xg  home_shots  away_shots  ...  \
# ...

# %%
df.head()
# Out:
#    match_id                date home_team            away_team  home_goals  \
# 0      5826 2014-08-23 18:00:00    Malaga        Athletic Club           1
# 1      5827 2014-08-23 20:00:00   Sevilla             Valencia           1
# 2      5828 2014-08-23 20:00:00   Granada  Deportivo La Coruna           2
# 3      5829 2014-08-23 22:00:00   Almeria             Espanyol           1
# 4      5830 2014-08-24 18:00:00     Eibar        Real Sociedad           1
#
#    away_goals  home_xg  away_xg  home_shots  away_shots  ...  home_deep  \
# 0           0     1.32     1.14          12          12  ...          4
# 1           1     1.17     1.75          12          11  ...          8
# 2           1     0.55     0.38          10           8  ...          2
# 3           1     0.98     0.40          19          12  ...          5
# 4           0     0.47     0.98          12          19  ...          4
#
#    away_deep  home_ppda  away_ppda  home_xpts  away_xpts  season_mapped  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
col = []

for i in df.columns:
    if df[i].dtype=='object':
        col.append(i)

# %%
col
# Out:
# ['home_team', 'away_team', 'season_mapped', 'Result']

# %%
le=LabelEncoder()

# %%
for co in col:
    df[co]=le.fit_transform(df[co])
    print(le.classes_)
# Out:
# ['Alaves' 'Almeria' 'Athletic Club' 'Atletico Madrid' 'Barcelona' 'Cadiz'
#  'Celta Vigo' 'Cordoba' 'Deportivo La Coruna' 'Eibar' 'Elche' 'Espanyol'
#  'Getafe' 'Girona' 'Granada' 'Las Palmas' 'Leganes' 'Levante' 'Malaga'
#  'Mallorca' 'Osasuna' 'Rayo Vallecano' 'Real Betis' 'Real Madrid'
#  'Real Sociedad' 'Real Valladolid' 'SD Huesca' 'Sevilla' 'Sporting Gijon'
#  'Valencia' 'Villarreal']
# ['Alaves' 'Almeria' 'Athletic Club' 'Atletico Madrid' 'Barcelona' 'Cadiz'
#  'Celta Vigo' 'Cordoba' 'Deportivo La Coruna' 'Eibar' 'Elche' 'Espanyol'
#  'Getafe' 'Girona' 'Granada' 'Las Palmas' 'Leganes' 'Levante' 'Malaga'
#  'Mallorca' 'Osasuna' 'Rayo Vallecano' 'Real Betis' 'Real Madrid'
#  'Real Sociedad' 'Real Valladolid' 'SD Huesca' 'Sevilla' 'Sporting Gijon'
#  'Valencia' 'Villarreal']
# ['2014-15' '2015-16' '2016-17' '2017-18' '2018-19' '2019-20' '2020-21'
#  '2021-22' '2022-23' '2023-24' '2024-25']
# ['away' 'draw' 'home']

# %% [markdown]
# PREDICTING HOME GOALS

# %%
df1 = df.filter(['home_team', 'away_team', 'home_form_points_avg', 'away_form_points_avg', 'home_ppda',], axis = 1)

# %%
df1
# Out:
#       home_team  away_team  home_form_points_avg  away_form_points_avg  \
# 0            18          2                   1.0                   1.0
# 1            27         29                   1.0                   1.0
# 2            14          8                   1.0                   1.0
# 3             1         11                   1.0                   1.0
# 4             9         24                   1.0                   1.0
# ...         ...        ...                   ...                   ...
# 4175          0         20                   2.0                   2.0
# 4176         12          6                   1.4                   2.2
# 4177         13          3                   1.6                   1.8
# 4178         30         27                   2.6                   1.4
# 4179          2          4                   2.6                   3.0
#
#       home_ppda
# 0         12.07
# 1          9.42
# 2          4.78
# 3          6.67
# 4          8.79
# ...

# %%
X = df1.drop(['home_ppda'], axis=1)
y = df1['home_ppda']

# %%
split_idx = int(len(X) * 0.8)
X_train = X.iloc[:split_idx]
X_test = X.iloc[split_idx:]
y_train = y.iloc[:split_idx]
y_test = y.iloc[split_idx:]

# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

# %%
model = RandomForestRegressor(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
model.score(X_train, y_train)
# Out:
# 0.8365051951121287

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 3.824010055394167

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 28.51297624889925

# %%
import joblib
joblib.dump(model, 'laliga_hppda.joblib')
joblib.dump(le, 'laliga_le.joblib')
# Out:
# ['laliga_le.joblib']

# %% [markdown]
# PREDICTING AWAY GOALS

# %%
df2 = df.filter(['home_team', 'away_team', 'home_form_points_avg', 'away_form_points_avg', 'home_ppda', 'away_ppda',], axis = 1)

# %%
X = df2.drop(['away_ppda'], axis=1)
y = df2['away_ppda']

# %%
split_idx = int(len(X) * 0.8)
X_train = X.iloc[:split_idx]
X_test = X.iloc[split_idx:]
y_train = y.iloc[:split_idx]
y_test = y.iloc[split_idx:]

# %%
model2 = RandomForestRegressor(random_state=42)
model2.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
model2.score(X_train, y_train)
# Out:
# 0.8810160547338534

# %%
y_pred = model2.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 4.569875717703349

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 49.57603010936603

# %%
import joblib
joblib.dump(model2, 'laliga_appda.joblib')
# Out:
# ['laliga_appda.joblib']

# %% [markdown]
# PREDICTING HOME EXPECTED GOALS

# %%
df3 = df.filter(['home_team', 'away_team', 'home_form_points_avg', 'away_form_points_avg', 'home_ppda', 'away_ppda', 'home_xg'], axis=1)

# %%
df3
# Out:
#       home_team  away_team  home_form_points_avg  away_form_points_avg  \
# 0            18          2                   1.0                   1.0
# 1            27         29                   1.0                   1.0
# 2            14          8                   1.0                   1.0
# 3             1         11                   1.0                   1.0
# 4             9         24                   1.0                   1.0
# ...         ...        ...                   ...                   ...
# 4175          0         20                   2.0                   2.0
# 4176         12          6                   1.4                   2.2
# 4177         13          3                   1.6                   1.8
# 4178         30         27                   2.6                   1.4
# 4179          2          4                   2.6                   3.0
#
#       home_ppda  away_ppda  home_xg
# 0         12.07       6.30     1.32
# 1          9.42      10.65     1.17
# ...

# %%
X = df3.drop(['home_xg'], axis=1)
y = df3['home_xg']

# %%
split_idx = int(len(X) * 0.8)
X_train = X.iloc[:split_idx]
X_test = X.iloc[split_idx:]
y_train = y.iloc[:split_idx]
y_test = y.iloc[split_idx:]

# %%
model3 = RandomForestRegressor(random_state=42)
model3.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
model3.score(X_train, y_train)
# Out:
# 0.8752997624611678

# %%
y_pred = model3.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 0.7039698564593302

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 0.8104977365550239

# %%
import joblib
joblib.dump(model3, 'laliga_hxg.joblib')
# Out:
# ['laliga_hxg.joblib']

# %% [markdown]
# PREDICTING AWAY EXPECTED GOALS

# %%
df4 = df.filter(['home_team', 'away_team', 'home_form_points_avg', 'away_form_points_avg', 'home_ppda', 'away_ppda','home_xg', 'away_xg'], axis=1)

# %%
df4
# Out:
#       home_team  away_team  home_form_points_avg  away_form_points_avg  \
# 0            18          2                   1.0                   1.0
# 1            27         29                   1.0                   1.0
# 2            14          8                   1.0                   1.0
# 3             1         11                   1.0                   1.0
# 4             9         24                   1.0                   1.0
# ...         ...        ...                   ...                   ...
# 4175          0         20                   2.0                   2.0
# 4176         12          6                   1.4                   2.2
# 4177         13          3                   1.6                   1.8
# 4178         30         27                   2.6                   1.4
# 4179          2          4                   2.6                   3.0
#
#       home_ppda  away_ppda  home_xg  away_xg
# 0         12.07       6.30     1.32     1.14
# ...

# %%
X = df4.drop(['away_xg'], axis=1)
y = df4['away_xg']

# %%
split_idx = int(len(X) * 0.8)
X_train = X.iloc[:split_idx]
X_test = X.iloc[split_idx:]
y_train = y.iloc[:split_idx]
y_test = y.iloc[split_idx:]

# %%
model4 = RandomForestRegressor(random_state=42)
model4.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
model4.score(X_train, y_train)
# Out:
# 0.8738999736498654

# %%
y_pred = model4.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 0.6066635167464115

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 0.5890521774760766

# %%
import joblib
joblib.dump(model4, 'laliga_axg.joblib')
# Out:
# ['laliga_axg.joblib']

# %% [markdown]
# PREDICTING HOME SHOTS ON TARGET

# %%
df5 = df.filter(['home_team', 'away_team', 'home_form_points_avg', 'away_form_points_avg',  'home_ppda', 'away_ppda','home_xg', 'away_xg', 'home_sot'], axis=1)

# %%
df5.head()
# Out:
#    home_team  away_team  home_form_points_avg  away_form_points_avg  \
# 0         18          2                   1.0                   1.0
# 1         27         29                   1.0                   1.0
# 2         14          8                   1.0                   1.0
# 3          1         11                   1.0                   1.0
# 4          9         24                   1.0                   1.0
#
#    home_ppda  away_ppda  home_xg  away_xg  home_sot
# 0      12.07       6.30     1.32     1.14         3
# 1       9.42      10.65     1.17     1.75         3
# 2       4.78       5.80     0.55     0.38         3
# 3       6.67      15.80     0.98     0.40         6
# 4       8.79       6.67     0.47     0.98         5

# %%
X = df5.drop(['home_sot'], axis=1)
y = df5['home_sot']

# %%
split_idx = int(len(X) * 0.8)
X_train = X.iloc[:split_idx]
X_test = X.iloc[split_idx:]
y_train = y.iloc[:split_idx]
y_test = y.iloc[split_idx:]

# %%
model5 = RandomForestRegressor(random_state=42)
model5.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
model5.score(X_train, y_train)
# Out:
# 0.920084862629562

# %%
y_pred = model5.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 1.5858373205741625

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 3.957572009569378

# %%
import joblib
joblib.dump(model5, 'laliga_hsot.joblib')
# Out:
# ['laliga_hsot.joblib']

# %% [markdown]
# PREDICTING AWAY SHOTS ON TARGET

# %%
df6 = df.filter(['home_team', 'away_team', 'home_form_points_avg', 'away_form_points_avg', 'home_ppda', 'away_ppda', 'home_xg', 'away_xg', 'home_sot', 'away_sot'], axis=1)

# %%
X = df6.drop(['away_sot'], axis=1)
y = df6['away_sot']

# %%
split_idx = int(len(X) * 0.8)
X_train = X.iloc[:split_idx]
X_test = X.iloc[split_idx:]
y_train = y.iloc[:split_idx]
y_test = y.iloc[split_idx:]

# %%
model6 = RandomForestRegressor(random_state=42)
model6.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
model6.score(X_train, y_train)
# Out:
# 0.9197615306106607

# %%
y_pred = model6.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 1.3261722488038274

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 2.8582523923444976

# %%
import joblib
joblib.dump(model6, 'laliga_asot.joblib')
# Out:
# ['laliga_asot.joblib']

# %% [markdown]
# PREDICTING 3 WAY

# %%
df8 = df.filter(['home_team', 'away_team', 'home_form_points_avg', 'away_form_points_avg', 'home_ppda', 'away_ppda', 'home_xg', 'away_xg', 'home_sot', 'away_sot', 'home_goals', 'away_goals', 'Result'], axis=1)

# %%
df8.Result.value_counts()
# Out:
# Result
# 2    1897
# 0    1197
# 1    1086
# Name: count, dtype: int64

# %%
df8
# Out:
#       home_team  away_team  home_form_points_avg  away_form_points_avg  \
# 0            18          2                   1.0                   1.0
# 1            27         29                   1.0                   1.0
# 2            14          8                   1.0                   1.0
# 3             1         11                   1.0                   1.0
# 4             9         24                   1.0                   1.0
# ...         ...        ...                   ...                   ...
# 4175          0         20                   2.0                   2.0
# 4176         12          6                   1.4                   2.2
# 4177         13          3                   1.6                   1.8
# 4178         30         27                   2.6                   1.4
# 4179          2          4                   2.6                   3.0
#
#       home_ppda  away_ppda  home_xg  away_xg  home_sot  away_sot  home_goals  \
# ...

# %%
X = df8.drop(['Result'], axis=1)
y = df8['Result']

# %%
split_idx = int(len(X) * 0.8)
X_train = X.iloc[:split_idx]
X_test = X.iloc[split_idx:]
y_train = y.iloc[:split_idx]
y_test = y.iloc[split_idx:]

# %%
model7 = RandomForestClassifier(random_state=42)
model7.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
model7.score(X_train, y_train)
# Out:
# 1.0

# %%
y_pred = model7.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.9964114832535885

# %%
import joblib
joblib.dump(model7, 'laliga_res.joblib')
# Out:
# ['laliga_res.joblib']

# %% [markdown]
# to predict pressing and game intensity

# %%
df10 = df.filter(['home_team', 'away_team', 'home_form_points_avg', 'away_form_points_avg', 'home_ppda', 'away_ppda', 'home_xg', 'away_xg', 'home_sot', 'away_sot', 'home_goals'], axis=1)

# %%
X = df10.drop(['home_goals'], axis=1)
y = df10['home_goals']

# %%
split_idx = int(len(X) * 0.8)
X_train = X.iloc[:split_idx]
X_test = X.iloc[split_idx:]
y_train = y.iloc[:split_idx]
y_test = y.iloc[split_idx:]

# %%
model10 = RandomForestRegressor(random_state=42)
model10.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
model10.score(X_train, y_train)
# Out:
# 0.9218351673849849

# %%
y_pred = model10.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 0.8103588516746412

# %%
import joblib
joblib.dump(model10, 'laliga_hgoals.joblib')
# Out:
# ['laliga_hgoals.joblib']

# %%
df9 = df.filter(['home_team', 'away_team', 'home_form_points_avg', 'away_form_points_avg', 'home_ppda', 'away_ppda', 'home_xg', 'away_xg', 'home_sot', 'away_sot', 'home_goals', 'away_goals'], axis=1)

# %%
X = df9.drop(['away_goals'], axis=1)
y = df9['away_goals']

# %%
split_idx = int(len(X) * 0.8)
X_train = X.iloc[:split_idx]
X_test = X.iloc[split_idx:]
y_train = y.iloc[:split_idx]
y_test = y.iloc[split_idx:]

# %%
model9 = RandomForestRegressor(random_state=42)
model9.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
model9.score(X_train, y_train)
# Out:
# 0.9209025923871758

# %%
import joblib
joblib.dump(model9, 'laliga_agoals.joblib')
# Out:
# ['laliga_agoals.joblib']
